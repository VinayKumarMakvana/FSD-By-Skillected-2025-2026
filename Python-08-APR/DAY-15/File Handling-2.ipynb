# %% [markdown]
# # **File Handling-2**

# %%
# Cursor -> Cursor is a current position inside a File.
with open("student.txt","w") as file:
  file.write("Vinay\nShubham")

# %%
# tell() :- tell() [function] current cursor positon
# seek() :- seek() change cursor position

# %%
with open("student.txt","r") as file:
  print(file.tell())
# Out:
# 0

# %%
with open("student.txt","r") as file:
  file.read(2)
  print(file.tell())
# Out:
# 2

# %%
# seek() :- moves cursir ti a specific position
with open("student.txt","r") as file:
  file.seek(3)
  print(file.read())
# Out:
# ay
# Shubham

# %%
# r+
with open("student.txt","r+") as file:
  data=file.read()
  print(data)
  file.write("\nNeha")
# Out:
# Vinay
# Shubham
# Neha
# Neha
# Neha

# %%
with open("student.txt","r+") as file:
  data=file.read()
  print(data)
# Out:
# Vinay
# Shubham
# Neha
# Neha
# Neha
# Neha

# %%
with open("student.txt","r+") as file:
  file.write("admin")

# %%
with open("student.txt","r+") as file:
  data=file.read()
  print(data)
# Out:
# admin
# Shubham
# Neha
# Neha
# Neha
# Neha

# %%
# What is w+ ?
with open("student.txt","w+") as file:
  file.write("Priya")
  print(file.read())
  file.seek(0)
  print(file.read(3))
  print(file.read())
# Out:
# Pri
# ya

# %%
# modes :-
  # r
  # w
  # a
  # r+
  # w+
  # cursor
  # seek()
  # tell()
  # with statement

# %%
# readline()
# file.readlines()

# %%
with open("student.txt","r") as file:
  for line in file:
    print(line)
# Out:
# Priya

# %%
# using os
import os
print(os.path.exists("student.txt"))
# Out:
# True

# %%
# explore :-
  # readline()
  # readlines()
  # truncate()
